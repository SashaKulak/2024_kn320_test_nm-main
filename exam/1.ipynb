# %% [markdown]
# ## Завдання на екзамен
# 1. У роботі №2, для файлу game/sword.py модифікувати метод bonus_poison щоб отрута тепер наносила шкоду мечу і забирала 2 vitality
# - пишемо код для реалізації нашого завдання
# ![](exam_code.png)
# - запустити код на виконання та представити результати
# - результат запуску на скріншоті
# ![](pytestpast.png)
